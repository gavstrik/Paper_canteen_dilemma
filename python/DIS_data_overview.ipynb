# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# Import data from tables 1-7 (excluding 7, Robins table)
data = [
    {'Number': (4, 5), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (5, 6), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'W'},
    {'Number': (7, 6), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (4, 5), 'Choice1': 'W', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'W'},
    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (6, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (6, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'b'},
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (9, 8), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'b'}
]

data += [
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (9, 10), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (6, 7), 'Choice1': 'W', 'Choice2': 'B'},
    {'Number': (10, 9), 'Choice1': 'B', 'Choice2': 'B'},
    {'Number': (5, 4), 'Choice1': 'W', 'Choice2': 'w'},
    {'Number': (4, 5), 'Choice1': 'W', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (3, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (5, 6), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (4, 5), 'Choice1': 'w', 'Choice2': 'w'}
]

data += [
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (7, 8), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (4, 3), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (4, 5), 'Choice1': 'w', 'Choice2': 'W'},
    {'Number': (2, 3), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (9, 8), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (3, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'}
]

data += [
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (7, 8), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (4, 3), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (4, 5), 'Choice1': 'w', 'Choice2': 'W'},
    {'Number': (2, 3), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (9, 8), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (3, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (8, 7), 'Choice1': 'b', 'Choice2': 'w'},
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'}
]

data += [
    {'Number': (6, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (4, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (9, 10), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (2, 3), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (6, 5), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (6, 7), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (4, 5), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (3, 4), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (3, 2), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (8, 7), 'Choice1': 'B', 'Choice2': 'W'},
    {'Number': (10, 9), 'Choice1': 'B', 'Choice2': 'B'},
    {'Number': (8, 9), 'Choice1': 'W', 'Choice2': 'B'},
    {'Number': (8, 7), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (5, 6), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (9, 8), 'Choice1': 'W', 'Choice2': 'B'}
]
data += [
    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (8, 9), 'Choice1': 'w', 'Choice2': 'b'},
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (4, 5), 'Choice1': 'W', 'Choice2': 'W'},
    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (9, 10), 'Choice1': 'b', 'Choice2': 'b'},
    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (6, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (3, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (7, 8), 'Choice1': 'w', 'Choice2': 'b'},
    {'Number': (4, 3), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (3, 4), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (4, 3), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (6, 5), 'Choice1': 'w', 'Choice2': 'w'},
    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'}
]

# Robins table
#data += [
#    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (9, 10), 'Choice1': 'b', 'Choice2': 'b'},
#    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
#    {'Number': (7, 6), 'Choice1': 'W', 'Choice2': 'B'},
#    {'Number': (2, 3), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (4, 3), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (4, 3), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (8, 9), 'Choice1': 'b', 'Choice2': 'b'},
#    {'Number': (6, 7), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (5, 4), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (9, 10), 'Choice1': 'b', 'Choice2': 'b'},
#    {'Number': (3, 2), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'},
#    {'Number': (5, 6), 'Choice1': 'w', 'Choice2': 'w'},
#    {'Number': (10, 9), 'Choice1': 'b', 'Choice2': 'b'}
#]
# Create a DataFrame
df = pd.DataFrame(data)

df['Choice1'] = df['Choice1'].str.lower()
df['Choice2'] = df['Choice2'].str.lower()
# Create dictionaries to store the counts for each number
number_counts = {}

# Populate the dictionaries
for index, row in df.iterrows():
    number_pair = row['Number']
    choice1 = row['Choice1']
    choice2 = row['Choice2']
    
    for num in number_pair:
        if num not in number_counts:
            number_counts[num] = {'w': 0, 'b': 0}
        
        if choice1 == 'w' or choice2 == 'w':
            number_counts[num]['w'] += 1
        if choice1 == 'b' or choice2 == 'b':
            number_counts[num]['b'] += 1

# Convert the dictionaries to a DataFrame
df2 = pd.DataFrame.from_dict(number_counts, orient='index')

# %%
df2.sort_index(ascending=True, inplace=True)
df2

# %%
import numpy as np

# %%
df2['Total'] = df2['w'] + df2['b']

# Calculate the percentage of 'w' and 'b' for each row
df2['w_percent'] = (df2['w'] / df2['Total']) * 100
df2['b_percent'] = (df2['b'] / df2['Total']) * 100

df2['w_percent'] = df2['w_percent'] / df2['w_percent'].max()
df2['b_percent'] = df2['b_percent'] / df2['b_percent'].max()

# Calculate the standard error of the mean (SEM)
df2['w_sem'] = np.sqrt((df2['w_percent'] * (1 - df2['w_percent'])) / df2['Total'])
df2['b_sem'] = np.sqrt((df2['b_percent'] * (1 - df2['b_percent'])) / df2['Total'])

df2

# %%
# !pip install seaborn

# %%
import seaborn as sns

# %%
import pandas as pd


# Create a DataFrame
df = pd.DataFrame(data)

# Create dictionaries to store the counts for each number
number_counts = {}

# Populate the dictionaries
for index, row in df.iterrows():
    number_pair = row['Number']
    choice1 = row['Choice1']
    choice2 = row['Choice2']
    
    for num in number_pair:
        if num not in number_counts:
            number_counts[num] = {'w': 0, 'b': 0}
        
        if choice1 == 'w' or choice2 == 'w':
            number_counts[num]['w'] += 1
        if choice1 == 'b' or choice2 == 'b':
            number_counts[num]['b'] += 1

# Convert the dictionaries to a DataFrame
number_counts_df = pd.DataFrame.from_dict(number_counts, orient='index')

number_counts

# Calculate the total count for each row
number_counts_df['Total'] = number_counts_df['w'] + number_counts_df['b']

# Calculate the percentage of 'w' and 'b' for each row
number_counts_df['w_percent'] = (number_counts_df['w'] / number_counts_df['Total']) * 100
number_counts_df['b_percent'] = (number_counts_df['b'] / number_counts_df['Total']) * 100

# Display the resulting DataFrame
number_counts_df = number_counts_df.sort_index()
display(number_counts_df)

# %%
x = range(2, 11)  # X-axis values from 2 to 10
plt.plot(x, number_counts_df['w_percent'], label='w')
#plt.plot(x, number_counts_df['b_percent'], label='b')

plt.xlabel('Number')
plt.ylabel('Percentage')
plt.title('Percentage of white')
plt.legend()
plt.xticks(x)  # Set x-axis ticks to match the data points
plt.grid(True)

plt.show()

# %%
x = range(2, 11)  # X-axis values from 2 to 10
n = 180  # Sample size

# Darker blue color
line_color = 'royalblue'

# Line plot with markers (dots)
sns.lineplot(x=x, y=df2['w_percent'], label=f'DIS (n={n})', errorbar='sd', marker='o', markersize=8, color=line_color)

# Plot confidence interval bands using standard error of the mean (SEM)
plt.fill_between(x, df2['w_percent'] - df2['w_sem'], df2['w_percent'] + df2['w_sem'], alpha=0.2, color=line_color)

# Add vertical lines for confidence intervals (darker blue)
plt.vlines(x, df2['w_percent'] - df2['w_sem'], df2['w_percent'] + df2['w_sem'], colors=line_color, alpha=0.8)

# Add blobs (matching darker blue)
plt.scatter(x, df2['w_percent'], color=line_color, s=50)

plt.xlabel('card number')
plt.ylabel("frequency of 'white' stone choice")
plt.legend()
plt.xticks(x)
plt.ylim(0.0, 1.05)  # Extend y-axis slightly above 1.0
plt.grid(True)

plt.show()

# %%
## Logistic Regression fit
